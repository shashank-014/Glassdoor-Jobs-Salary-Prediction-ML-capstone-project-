# %% [markdown]
# # Glassdoor Jobs Salary Prediction

# %% [markdown]
# ##### Project Type - Regression
# ##### Contribution - Individual

# %% [markdown]
# # Project Summary
#
# I built this project to turn a messy Glassdoor salary file into something I could actually explain clearly. I wanted the work to feel practical, so I kept the feature set readable and focused on what usually drives salary bands in job posts.

# %% [markdown]
# # Problem Statement
#
# My goal here is to estimate the salary range behind a job post and then explain which company and role details are pushing that estimate up or down.

# %%
from glassdoor_jobs_project_code_export import dataset_overview, load_data, project_summary, run_modeling

# %% [markdown]
# ## 1. What I checked first
#
# I start by checking the file shape, the missing values, and the salary text itself because that is the part that needs the most cleanup before I can trust anything else.

# %%
df = load_data()`noverview = dataset_overview(df)`ndf.head(), overview

# %% [markdown]
# ## 2. How I worked through it
#
# Once the data is usable, I compare a few regression models instead of forcing one answer too early. I also keep the output readable so I can talk through it in a live review.

# %%
results = run_modeling()`nresults["metrics"]`nresults["feature_importance"]

# %% [markdown]
# ## 3. My takeaway
#
# At the end, I focus on what I learned, not just on the score. I want the result to tell a salary story that makes sense to a recruiter or hiring team.

# %%
project_summary(results)
